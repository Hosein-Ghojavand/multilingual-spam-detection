# %%
# Purpose: Import necessary libraries for data manipulation, API calls, and text processing.

# Standard library imports
import os
import random
import re

# Third-party library imports
import pandas as pd
from tqdm import tqdm
from google import genai
from langchain_community.llms import Ollama
from langchain.schema import AIMessage, HumanMessage

# %%
# Purpose: Load the Gemini API key from an environment variable.

# Load the API key from an environment variable
YOUR_API_KEY = os.environ.get("GEMINI_API_KEY")

if YOUR_API_KEY is None:
    raise ValueError("GEMINI_API_KEY environment variable not set.")

# %%
# Purpose: Initialize the Gemini API client and define the call_gemini function.

from google import genai
from google.genai import types

# Initialize Google Gemini API client
client = genai.Client(api_key=YOUR_API_KEY)


def call_gemini(prompt_text, temperature=0.7, max_output_tokens=500, top_p=0.95, top_k=40):
    """
    Call the Gemini API to generate content with configurable parameters.

    Args:
        prompt_text (str): The prompt text to send to the Gemini API.
        temperature (float, optional): Controls the randomness of the output. Defaults to 0.7.
        max_output_tokens (int, optional): The maximum number of tokens in the output. Defaults to 500.
        top_p (float, optional): Nucleus sampling parameter. Defaults to 0.95.
        top_k (int, optional): Top-K sampling parameter. Defaults to 40.

    Returns:
        str: The generated text response from the Gemini API.
    """
    response = client.models.generate_content(
        model="gemini-2.0-flash-lite",  # Use the desired model -lite
        contents=prompt_text,
        config=types.GenerateContentConfig(
            temperature=temperature,          # Controls randomness
            max_output_tokens=max_output_tokens,  # Maximum tokens in the output
            topP=top_p,                       # Nucleus sampling
            topK=top_k                        # Top-K sampling
        )
    )
    return response.text  # Extract the text response

# %%
# Purpose: Load and preprocess the existing spam dataset.

import os

# Constants
DATASET_PATH = os.path.join('..', '..', '..', 'Data', 'English', '1. Main', 'english_sms.csv')
TEXT_COLUMN = 'v2'
CLASS_COLUMN = 'v1'
LABEL_COLUMN = 'label'
MESSAGE_COLUMN = 'message'

# Load and preprocess spam dataset
spam_data = pd.read_csv(DATASET_PATH, encoding='latin1')
spam_data = spam_data[["v1","v2"]]
spam_data = spam_data[[TEXT_COLUMN, CLASS_COLUMN]].rename(columns={CLASS_COLUMN: LABEL_COLUMN, TEXT_COLUMN: MESSAGE_COLUMN})


def load_existing_data():
    """
    Loads spam and ham messages from the dataset.

    Returns:
        tuple: A tuple containing two lists:
            - ham_samples (list): A list of ham messages.
            - spam_samples (list): A list of spam messages.
    """
    try:
        ham_samples = spam_data[spam_data[LABEL_COLUMN] == "ham"][MESSAGE_COLUMN].tolist()
        spam_samples = spam_data[spam_data[LABEL_COLUMN] == "spam"][MESSAGE_COLUMN].tolist()
        return ham_samples, spam_samples
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return [], []

# %%
# Revised generate_sms_batch function using the previous prompt template

def generate_sms_batch(category: str = "ham", num_samples: int = 10, messages_per_request: int = 5, temperature: float = 0.95):
    """
    Generates synthetic SMS messages in batches using the previous prompt template.
    Note: Text processing is removed and will be applied later on the generated dataset.

    Args:
        category (str, optional): The category of SMS messages ("ham" or "spam"). Defaults to "ham".
        num_samples (int, optional): Total number of messages to generate. Defaults to 10.
        messages_per_request (int, optional): Number of messages per API request. Defaults to 5.
        temperature (float, optional): Temperature parameter for text generation. Defaults to 0.95.

    Returns:
        List[str]: List of generated SMS messages.
    """
    ham_examples, spam_examples = load_existing_data()
    messages = []
    recent_messages = set()  # To prevent immediate repetition

    for i in range(0, num_samples, messages_per_request):
        example = random.choice(spam_examples if category == "spam" else ham_examples)
        show_example = (random.random() < 1.0)
        example_text = f"Here is an example of a {category} message: \"{example}\"" if show_example else "The messages should be natural and relevant."

        base_prompt = (
            f"You are an AI assistant tasked with generating **five realistic and natural SMS messages ({category}) in English**.\n"
            "Only generate the SMS messages without any additional text, numbering, or explanations.\n"
            f"{example_text}\n\n### Instructions:\n"
            "1. Keep each message **natural**.\n"
            "2. Use **conversational and diverse language**.\n"
            "3. Write each message **on a separate line**.\n"
            "4. Do not include any extra text, numbering, or explanations.\n"
        )

        if category == "ham":
            prompt = (
                base_prompt +
                "5. Messages can include **reminders, invitations, jokes, casual conversations, daily updates, motivational quotes, fun facts, announcements, or storytelling snippets**.\n"
                "6. Ensure the messages feel like part of a **real conversation**, not just random sentences.\n"
                "7. Use diverse topics such as **daily life, sports, food, travel, movies, family, technology, work, or school**.\n"
                "\nNow generate five natural SMS messages."
            )
        elif category == "spam":
            prompt = (
                base_prompt +
                "5. Messages should include **smart advertisements, promotional offers, lottery notifications, suspicious banking alerts, or loan offers**.\n"
                "6. Avoid overusing clichés like \"Congratulations, you won!\"; aim for **more creative and persuasive text**.\n"
                "7. Avoid being overly fake or repetitive.\n"
                "8. Use minimal emojis or symbols .\n"
                "\nNow generate five SMS messages."
            )
        else:
            raise ValueError("Invalid category. Choose 'ham' or 'spam'.")

        # Call the Gemini API using the constructed prompt
        raw_response = call_gemini(prompt, temperature=temperature)
        new_messages = raw_response.strip().split("\n")

        # Append the raw messages without processing
        for msg in new_messages:
            stripped_msg = msg.strip()
            if stripped_msg and stripped_msg not in recent_messages:
                messages.append(stripped_msg)
                recent_messages.add(stripped_msg)

    return messages

# %%
# Purpose: Generate a synthetic SMS dataset and save it incrementally as a CSV file.

import os
import pandas as pd
from tqdm import tqdm
from typing import List

def generate_dataset(num_ham: int = 500, num_spam: int = 500, output_file: str = "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv", batch_size: int = 10) -> None:
    """
    Generates a synthetic SMS dataset and saves it incrementally as a CSV file.

    Args:
        num_ham (int, optional): The number of ham messages to generate. Defaults to 500.
        num_spam (int, optional): The number of spam messages to generate. Defaults to 500.
        output_file (str, optional): The path to the output CSV file. Defaults to "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv".
        batch_size (int, optional): The number of messages to generate in each batch. Defaults to 10.
    """

    # Initialize or load existing dataset
    if os.path.exists(output_file):
        try:
            data = pd.read_csv(output_file)
            print(f"Loaded existing dataset with {len(data)} samples.")
        except Exception as e:
            print(f"Error loading existing dataset: {e}. Starting with an empty dataset.")
            data = pd.DataFrame(columns=["message", "label"])
    else:
        data = pd.DataFrame(columns=["message", "label"])

    # Track progress
    ham_generated = len(data[data["label"] == "ham"])
    spam_generated = len(data[data["label"] == "spam"])

    # Generate ham messages
    with tqdm(total=num_ham, initial=ham_generated, desc="Generating Ham Messages", unit="msg") as ham_progress:
        while ham_generated < num_ham:
            ham_batch = generate_sms_batch(category="ham", num_samples=min(batch_size, num_ham - ham_generated),temperature=0.8)
            new_ham_data = pd.DataFrame({"message": ham_batch, "label": ["ham"] * len(ham_batch)})
            data = pd.concat([data, new_ham_data], ignore_index=True)
            ham_generated += len(ham_batch)
            ham_progress.update(len(ham_batch))

    # Generate spam messages
    with tqdm(total=num_spam, initial=spam_generated, desc="Generating Spam Messages", unit="msg") as spam_progress:
        while spam_generated < num_spam:
            spam_batch = generate_sms_batch(category="spam", num_samples=min(batch_size, num_spam - spam_generated), temperature=0.8)
            new_spam_data = pd.DataFrame({"message": spam_batch, "label": ["spam"] * len(spam_batch)})
            data = pd.concat([data, new_spam_data], ignore_index=True)
            spam_generated += len(spam_batch)
            spam_progress.update(len(spam_batch))

    # Shuffle the dataset before saving
    data = data.sample(frac=1).reset_index(drop=True)

    # Save the dataset to a CSV file
    try:
        data.to_csv(output_file, index=False)
        print(f"Dataset generation completed. Saved to {output_file}. Total samples: {len(data)}")
    except Exception as e:
        print(f"Error saving dataset to {output_file}: {e}")

# %%
# Purpose: Generate the synthetic SMS dataset.

# Define the output file path
output_file = "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv"
# Check if the output directory exists
output_dir = os.path.dirname(output_file)
if not os.path.exists(output_dir):
    try:
        os.makedirs(output_dir)
        print(f"Created output directory: {output_dir}")
    except Exception as e:
        print(f"Error creating output directory: {e}. Please ensure the path is valid.")
        # Optionally, you can exit the script here if directory creation fails
        # return

# Generate dataset
generate_dataset(num_ham=1040, num_spam=1040, output_file=output_file)
# Out:
# Loaded existing dataset with 2011 samples.
# Generating Ham Messages: 1044msg [00:18,  3.88msg/s]
# Generating Spam Messages: 1042msg [00:01,  3.06msg/s]
# Dataset generation completed. Saved to ../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv. Total samples: 2086

# %%
# Purpose: Read the generated synthetic SMS dataset.

# Define the output file path
output_file = "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv"

# Read the synthetic dataset
try:
    synthetic = pd.read_csv(output_file)
    print(f"Successfully loaded synthetic dataset from {output_file} with {len(synthetic)} rows.")
    print(synthetic)  # Display the first few rows
except FileNotFoundError:
    print(f"Error: The file {output_file} was not found. Please ensure the dataset has been generated.")
except Exception as e:
    print(f"An error occurred while reading the dataset: {e}")
# Out:
# Successfully loaded synthetic dataset from ../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv with 2086 rows.
#                                                 message label
# 0     Hey! Just saw your recent Instagram post. Thin...  spam
# 1     Urgent! Your loan application is approved. Get...  spam
# 2     Want to grab pizza and watch the game tonight?...   ham
# 3     🔥💰 Limited-time offer: Upgrade your phone for ...  spam
# 4     You've been selected as a finalist for our $10...  spam
# ...                                                 ...   ...
# 2081  Crazy weather, huh? Hope you're having a good ...   ham
# 2082  Hey Chris Martinez, your ticket number has won...  spam
# 2083   On my way to the gym, wanna join? Leg day today!   ham
# 2084  Big presentation went well! Time to celebrate ...   ham
# 2085  Hey, still keen for the game tonight? Kick off...   ham
#
# [2086 rows x 2 columns]

# %%
# Purpose: Extract the SMS messages from the synthetic dataset into a list.

# Extract messages from the synthetic dataset
if not synthetic.empty:
    messages = synthetic["message"].tolist()
    print(f"Extracted {len(messages)} messages from the synthetic dataset.")
else:
    print("The synthetic dataset is empty. No messages were extracted.")
    messages = []
# Out:
# Extracted 2086 messages from the synthetic dataset.

# %% [markdown]
# .
#
# .
#
# .
#
# .
#
# .
#
#
# ### lets define some function  to prcec the output samples

# %%
# Purpose: Consolidate all text processing functions into a single cell.

import re
from typing import List, Tuple
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def clean_message(raw_text: str) -> str:
    """
    Removes the AI's thought process enclosed in <think>...</think> tags.

    Args:
        raw_text (str): The input text that may contain <think>...</think> tags.

    Returns:
        str: The cleaned text with the <think>...</think> tags removed.
    """
    return re.sub(r"<think>.*?</think>", "", raw_text, flags=re.DOTALL).strip()

def clean_numbered_messages(message: str) -> str:
    """
    Remove numbers and dots at the beginning of an English SMS message.

    Args:
        message (str): The input message containing numbers and dots.

    Returns:
        str: The cleaned message without leading numbers and dots.
    """
    return re.sub(r"^\d+\.\s*", "", message).strip()

def remove_numbers_from_messages(message: str) -> str:
    """
    Remove numbers and associated punctuation at the beginning of an English SMS message.

    Args:
        message (str): The input message containing numbers and punctuation.

    Returns:
        str: The cleaned message without leading numbers and punctuation.
    """
    return re.sub(r"^\s*\d+[.\)\-:\s]?\s*", "", message).strip()

def replace_placeholders(message: str) -> str:
    """
    Replace placeholders in the generated English SMS message with realistic values.

    Args:
        message (str): The input message containing placeholders.

    Returns:
        str: The message with placeholders replaced by realistic values.
    """
    import random

    fake_phone = f"+1-{random.randint(200, 999)}-{random.randint(200, 999)}-{random.randint(1000, 9999)}"
    fake_account_number = f"{random.randint(4000, 4999)}-{random.randint(1000, 9999)}-{random.randint(1000, 9999)}-{random.randint(1000, 9999)}"
    fake_url = f"https://www.{random.choice(['example', 'myshop', 'secure', 'bestdeals', 'onlinestore'])}{random.randint(1, 999)}.com"
    fake_website_name = f"{random.choice(['example', 'myshop', 'secure', 'bestdeals', 'onlinestore'])}{random.randint(1, 999)}.com"
    fake_store_name = f"Store {random.choice(['USA', 'Online', 'Global', 'Tech', 'Mart', 'Shop', 'Express', 'Depot', 'Bazaar', 'Outlet'])}"
    fake_name = f"{random.choice(['John', 'Jane', 'Alex', 'Emily', 'Chris', 'Taylor', 'Jordan', 'Morgan', 'Sam', 'Casey'])} {random.choice(['Smith', 'Johnson', 'Brown', 'Williams', 'Jones', 'Garcia', 'Miller', 'Davis', 'Martinez', 'Hernandez'])}"
    fake_telegram_link = f"https://t.me/fakechannel{random.randint(1, 10)}"
    fake_code = f"{random.randint(1000, 9999)}"

    replacements = {
        "[FAKE_LINK]": fake_url,
        "[PHISHING_LINK]": fake_url,
        "[LINK]": fake_url,
        "[Link]": fake_url,
        "[link]": fake_url,
        "[Name]": fake_name,
        "[name]": fake_name,
        "[store name]": fake_store_name,
        "[Store Name]": fake_store_name,
        "[shop name]": fake_store_name,
        "[Shop Name]": fake_store_name,
        "[ACCOUNT_NUMBER]": fake_account_number,
        "[WEBSITE_NAME]": fake_website_name,
        "[website address]": fake_website_name,
        "[Link to Site]": fake_url,
        "[link to site]": fake_url,
        "[website link]": fake_website_name,
        "[STORE_LINK]": fake_url,
        "[WEBSITE_LINK]": fake_url,
        "[SITE_LINK]": fake_url,
        "[INSTITUTE_NAME]": fake_store_name,
        "[SITE_ADDRESS]": fake_url,
        "[REGISTRATION_LINK]": fake_url,
        "[TELEGRAM_LINK]": fake_telegram_link,
        "[FAKE_PHONE_NUMBER]": fake_phone,
        "[PHONE_NUMBER]": fake_phone,
        "[number]": fake_phone,
        "[PHONE]": fake_phone,
        "[SHORT_LINK]": fake_url,
        "[ADDRESS]": fake_url,
        "[LOAN_LINK]": fake_url,
        "[PURCHASE_LINK]": fake_url,
        "[ACTIVATION_CODE]": fake_code,
        "[PROMOTIONAL_LINK]": fake_url,
        "[SHORTENED_LINK]": fake_url,
        "[FAKE_LINK]": fake_url,
        "[REGISTRATION_LINK]": fake_url,
        "[SCAM_LINK]": fake_url,
        "[INVALID_LINK]": fake_url,
        "[FAKE_CODE]": fake_code,
        "[DISCOUNT_CODE]": fake_code,
        "[VERIFICATION_CODE]": fake_code,
        "[AUTHENTICATION_CODE]": fake_code,
        "[ACTIVATION_CODE]": fake_code,
        "[CONTACT_NUMBER]": fake_phone,
        "[PHONE]": fake_phone,
        "[STORE_NAME]": fake_store_name,
        "[ADDRESS/CONTACT]": fake_store_name,
    }

    for placeholder, replacement in replacements.items():
        message = message.replace(placeholder, replacement)

    return message

from typing import List, Tuple
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def identify_similar_messages(messages: List[str], threshold: float = 0.8) -> Tuple[List[str], List[Tuple[str, str, float]], List[int]]:
    """
    Identifies and removes pairs of messages that are too similar to each other based on cosine similarity.

    Args:
        messages (List[str]): A list of SMS messages.
        threshold (float, optional): The similarity threshold. Defaults to 0.8.

    Returns:
        Tuple[List[str], List[Tuple[str, str, float]], List[int]]: A tuple containing:
            - A list of unique messages.
            - A list of similar message pairs with their similarity scores.
            - A list of indices of the unique messages in the original list.
    """
    # Vectorize the messages using TF-IDF
    vectorizer = TfidfVectorizer().fit_transform(messages)
    similarity_matrix = cosine_similarity(vectorizer)

    similar_pairs = []
    unique_messages = []
    unique_indices = []  # Keep track of the indices of unique messages

    for i, message in enumerate(messages):
        is_unique = True
        for unique_index in unique_indices:
            # Calculate cosine similarity between the current message and the unique message
            similarity = similarity_matrix[i, unique_index]

            # If the similarity is above the threshold, mark the current message as not unique
            if similarity > threshold:
                similar_pairs.append((messages[i], messages[unique_index], similarity))
                is_unique = False
                break

        # If the message is unique, add it to the list of unique messages and its index to the list of unique indices
        if is_unique:
            unique_messages.append(messages[i])
            unique_indices.append(i)

    return unique_messages, similar_pairs, unique_indices

# %% [markdown]
# .
#
#
#
# .
#
#
#
# .
#
#
#
# .
#
#
#
# .
#
#
# #### now let's execute them on the data

# %%
# Revised cell: Process synthetic SMS text with progress bars and detailed deletion logs

import pandas as pd
import numpy as np
from tqdm import tqdm

def process_synthetic_text_with_progress(df):
    """
    Applies text processing functions to the 'message' column with progress bars.
    Handles missing values, identifies similar messages, and saves the cleaned dataset.

    Args:
        df (pd.DataFrame): DataFrame containing the synthetic SMS messages.

    Returns:
        pd.DataFrame: DataFrame with processed messages.
    """
    # Step 1: Handle missing values
    print("Step 1: Handling missing values...")
    with tqdm(total=len(df), desc="Filling NaN values", unit="msg") as pbar:
        df["message"] = df["message"].fillna("")
        pbar.update(len(df))

    # Step 2: Apply cleaning functions
    print("Step 2: Cleaning messages...")
    with tqdm(total=len(df), desc="Cleaning messages", unit="msg") as pbar:
        df["message"] = df["message"].apply(
            lambda x: replace_placeholders(
                remove_numbers_from_messages(
                    clean_message(str(x))
                )
            )
        )
        pbar.update(len(df))

    # Step 3: Identify and remove similar messages
    print("Step 3: Identifying and removing similar messages...")
    messages = df["message"].tolist()
    unique_messages, similar_pairs, unique_indices = identify_similar_messages(messages, threshold=0.75)

    # Log similar messages that will be removed
    if similar_pairs:
        print("Similar messages identified for removal:")
        for msg1, msg2, similarity in similar_pairs:
            print(f"Message 1: {msg1}")
            print(f"Message 2: {msg2}")
            print(f"Similarity: {similarity:.4f}")
            print("-" * 50)

    # Progress bar for removing similar messages
    with tqdm(total=len(messages) - len(unique_messages), desc="Removing similar messages", unit="msg") as pbar:
        df = df.iloc[unique_indices].copy()
        pbar.update(len(messages) - len(unique_messages))

    # Reset index after processing
    df.reset_index(drop=True, inplace=True)
    return df


# Define the path to the synthetic dataset CSV file
input_file = "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv"
output_file = "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv"  # New output file

# Load the synthetic dataset, process the text, and save it to a new file
try:
    synthetic_df = pd.read_csv(input_file)
    print(f"Loaded synthetic dataset with {len(synthetic_df)} rows.")
    print("Sample before processing:")
    print(synthetic_df.head())

    processed_df = process_synthetic_text_with_progress(synthetic_df.copy())

    # Save the processed dataset to a NEW CSV file
    processed_df.to_csv(output_file, index=False)
    print(f"Synthetic dataset text processed and saved successfully to {output_file}")

except FileNotFoundError:
    print(f"Error: Input file not found: {input_file}")
except Exception as e:
    print(f"Error processing synthetic dataset: {e}")
# Out:
# Loaded synthetic dataset with 2086 rows.
# Sample before processing:
#                                              message label
# 0  Hey! Just saw your recent Instagram post. Thin...  spam
# 1  Urgent! Your loan application is approved. Get...  spam
# 2  Want to grab pizza and watch the game tonight?...   ham
# 3  🔥💰 Limited-time offer: Upgrade your phone for ...  spam
# 4  You've been selected as a finalist for our $10...  spam
# Step 1: Handling missing values...
# Filling NaN values: 100%|██████████| 2086/2086 [00:00<?, ?msg/s]
# Step 2: Cleaning messages...
# Cleaning messages: 100%|██████████| 2086/2086 [00:00<00:00, 57574.18msg/s]
# Step 3: Identifying and removing similar messages...
# Similar messages identified for removal:
# Message 1: Did you see the game last night?! Crazy finish!
# Message 2: Hey, did you see the game last night?! Crazy finish!
# Similarity: 0.9778
# --------------------------------------------------
# Message 1: Ugh, my phone died. Can you send me the address again?
# Message 2: Ugh, my phone died. Can you send me the address again?
# Similarity: 1.0000
# --------------------------------------------------
# Message 1: Hey, did you finish that report yet?
# Message 2: Did you finish that report yet?
# Similarity: 0.9680
# --------------------------------------------------
# Message 1: Hey, did you see that crazy play last night?!
# Message 2: Hey, did you see that crazy play last night?!
# Similarity: 1.0000
# --------------------------------------------------
# Message 1: Hey, still up for dinner tonight? Thinking Italian!
# Message 2: Hey, still up for dinner tonight? Thinking Italian?
# Similarity: 1.0000
# --------------------------------------------------
# Message 1: Heads up, the meeting got moved to 2 PM.
# Message 2: Hey, just a heads up, the meeting got moved to 2 pm.
# Similarity: 0.9622
# --------------------------------------------------
# Message 1: Thinking of ordering pizza tonight. Want in?
# Message 2: Thinking of ordering pizza tonight, you in?
# Similarity: 0.8919
# --------------------------------------------------
# Message 1: Just got back from the gym, feeling great!
# Message 2: Just got back from the gym - feeling amazing! You in tomorrow?
# Similarity: 0.7601
# --------------------------------------------------
# Message 1: Hey, still on for dinner tonight?
# Message 2: Hey, you still up for dinner tonight?
# Similarity: 0.8468
# --------------------------------------------------
# Message 1: Just saw that new movie trailer - looks insane! Wanna go this weekend?
# Message 2: Just saw the trailer for that new movie - looks good! Wanna go this weekend?
# Similarity: 0.8657
# --------------------------------------------------
# Message 1: Hey, are you still coming over tonight? Pizza's on me!
# Message 2: Hey, are you still coming over later?
# Similarity: 0.7501
# --------------------------------------------------
# Message 1: Just finished making dinner - wanna come over later?
# Message 2: Just finished making a lasagna, wanna come over for dinner tonight?
# Similarity: 0.7955
# --------------------------------------------------
# Message 1: Just got back from the gym, feeling great! What are you up to?
# Message 2: Just finished the gym, feeling great! What are you up to?
# Similarity: 0.8176
# --------------------------------------------------
# Message 1: Thinking of ordering pizza tonight, wanna join?
# Message 2: Thinking of ordering pizza tonight, you in?
# Similarity: 0.7600
# --------------------------------------------------
# Message 1: Hey, you still coming over later? Pizza's on me!
# Message 2: Hey, are you still coming over later?
# Similarity: 0.7719
# --------------------------------------------------
# Message 1: Need a ride to the airport tomorrow morning? Let me know!
# Message 2: Need a ride to the airport tomorrow morning?
# Similarity: 0.8392
# --------------------------------------------------
# Message 1: Hey, did you see that crazy play in the game last night?!
# Message 2: Hey, did you see the game last night?! Crazy finish!
# Similarity: 0.7768
# --------------------------------------------------
# Message 1: Ugh, stuck in traffic. Be there in like, an hour!
# Message 2: Ugh, this traffic is insane. Should be there in like...an hour?
# Similarity: 0.7717
# --------------------------------------------------
# Message 1: Just saw the cutest dog at the park. Made my day!
# Message 2: Just saw the cutest dog, made my day!
# Similarity: 0.8741
# --------------------------------------------------
# Message 1: Just finished that book you recommended. Wow!
# Message 2: Just finished that book you recommended - wow! Let's chat later?
# Similarity: 0.7737
# --------------------------------------------------
# Message 1: Hey, are you still coming over tonight? Pizza's on me!
# Message 2: Hey, are you still coming over later?
# Similarity: 0.7501
# --------------------------------------------------
# Message 1: Running late, traffic is a nightmare! Be there as soon as I can.
# Message 2: Running a bit late, traffic is a nightmare. Be there as soon as I can!
# Similarity: 0.9485
# --------------------------------------------------
# Message 1: Running late, traffic is a nightmare. Be there as soon as I can!
# Message 2: Running a bit late, traffic is a nightmare. Be there as soon as I can!
# Similarity: 0.9485
# --------------------------------------------------
# Message 1: Almost done with this presentation, then freedom!
# Message 2: Almost done with the presentation, then freedom!
# Similarity: 0.9594
# --------------------------------------------------
# Message 1: Forgot to grab milk at the store. Could you pick some up? Thanks!
# Message 2: Forgot to grab milk at the store. Could you pick some up?
# Similarity: 0.9143
# --------------------------------------------------
# Message 1: Driving home now. See you soon!
# Message 2: Driving home now, see you soon!
# Similarity: 1.0000
# --------------------------------------------------
# Message 1: Heard back from the job. Fingers crossed!
# Message 2: Heard back from that job yet? Fingers crossed for you!
# Similarity: 0.8745
# --------------------------------------------------
# Message 1: Did you remember to take the chicken out to defrost?
# Message 2: Did you remember to take the chicken out to defrost?
# Similarity: 1.0000
# --------------------------------------------------
# Message 1: Ugh, this traffic is insane. Running super late for dinner.
# Message 2: Ugh, this traffic is insane! Running late for dinner.
# Similarity: 0.8635
# --------------------------------------------------
# Message 1: Forgot to tell you, my flight got delayed. Ugh.
# Message 2: Forgot to tell you, my flight got delayed. Ugh.
# Similarity: 1.0000
# --------------------------------------------------
# Message 1: Hey, just a heads up, the meeting got moved to 2pm.
# Message 2: Hey, just a heads up, the meeting got moved to 2 pm.
# Similarity: 0.7662
# --------------------------------------------------
# Message 1: Just saw the new Avengers trailer - gonna be epic!
# Message 2: Just saw the new Avengers trailer! Gonna be epic. Wanna see it opening weekend?
# Similarity: 0.8190
# --------------------------------------------------
# Message 1: Running late, traffic is a nightmare! Be there soon!
# Message 2: Running a little late, traffic is a nightmare. Be there soon!
# Similarity: 0.9072
# --------------------------------------------------
# Message 1: OMG, the traffic is insane today. Still stuck on the highway.
# Message 2: Ugh, this traffic is insane. Stuck on the highway!
# Similarity: 0.7698
# --------------------------------------------------
# Message 1: Finally finished that project! Feeling so relieved and ready for the weekend.
# Message 2: Finally finished that project! Feeling relieved.
# Similarity: 0.7979
# --------------------------------------------------
# Message 1: Hey, are you still up for dinner tonight?
# Message 2: Hey, you still up for dinner tonight?
# Similarity: 0.8860
# --------------------------------------------------
# Removing similar messages: 100%|██████████| 36/36 [00:00<?, ?msg/s]
# Synthetic dataset text processed and saved successfully to ../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv

# %%
synthetic = pd.read_csv("../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv")
synthetic
# Out:
#                                                 message label
# 0     Hey! Just saw your recent Instagram post. Thin...  spam
# 1     Urgent! Your loan application is approved. Get...  spam
# 2     Want to grab pizza and watch the game tonight?...   ham
# 3     🔥💰 Limited-time offer: Upgrade your phone for ...  spam
# 4     You've been selected as a finalist for our $10...  spam
# ...                                                 ...   ...
# 2045  Crazy weather, huh? Hope you're having a good ...   ham
# 2046  Hey Chris Martinez, your ticket number has won...  spam
# 2047   On my way to the gym, wanna join? Leg day today!   ham
# 2048  Big presentation went well! Time to celebrate ...   ham
# 2049  Hey, still keen for the game tonight? Kick off...   ham
#
# [2050 rows x 2 columns]

# %%
for i in range(len(synthetic)):
    print(f"{i + 1}.[{synthetic['label'][i]}]: {synthetic['message'][i]}")
# Out:
# 1.[spam]: Hey! Just saw your recent Instagram post. Thinking of upgrading your phone? Check out our deals: https://www.onlinestore276.com
# 2.[spam]: Urgent! Your loan application is approved. Get funds today. Apply here: https://www.onlinestore256.com
# 3.[ham]: Want to grab pizza and watch the game tonight? My treat!
# 4.[spam]: 🔥💰 Limited-time offer: Upgrade your phone for only $99! Shop now before they're gone: https://www.onlinestore256.com
# 5.[spam]: You've been selected as a finalist for our $1000 shopping spree! Complete your registration to claim your prize: [fake prize website]
# 6.[ham]: Hey, did you remember to DVR the game tonight? I'm gonna be late getting home.
# 7.[ham]: That meeting got pushed back to Thursday, FYI.
# 8.[spam]: Claim your free gift card worth $100! Click here to redeem: https://www.secure893.com Offer ends soon! 🔥
# 9.[spam]: You've been selected for a prize draw! Claim your reward: https://www.onlinestore91.com
# 10.[ham]: OMG, you won't believe what happened at the coffee shop today! Call me.
# 11.[spam]: Your entry to the Dream Raffle is confirmed. Check your results on Friday!
# 12.[ham]: Did you finish that report? I need a quick look over.
# 13.[spam]: Hey, it's Sarah from your local branch. We pre-approved you for a home equity loan with rates as low as 3.99%. Call me at 555-1234 if you're interested.
# 14.[spam]: Hey! Your Amazon order is ready for pickup. Get 20% off your next purchase with code PICKUPNOW.
# 15.[ham]: Just landed in Barcelona! The city is buzzing. Sending pics soon!
# 16.[spam]: Need a quick loan? Apply online now and get cash within hours. No credit check: https://www.example653.com
# 17.[ham]: Don't forget we're meeting Sarah for coffee at 2 PM tomorrow.
# 18.[ham]: Just got back from the grocery store. Need anything?
# 19.[ham]: Hey, did you finish that book you were reading? Thinking about starting a new one.
# 20.[spam]: Get pre-approved for a loan up to $50,000. Apply now: https://www.onlinestore671.com
# 21.[ham]: Just grabbed the ingredients for that pasta you love! Dinner at mine tomorrow?
# 22.[ham]: Just finished making a lasagna, wanna come over for dinner tonight?
# 23.[ham]: OMG, this pizza is incredible! You HAVE to try it.
# 24.[spam]: Hey, your Amazon order is ready for pickup! Click here to schedule: https://www.myshop497.com
# 25.[ham]: Almost at the airport! Flight's on time.
# 26.[ham]: Any good movies out this weekend? Thinking of catching something.
# 27.[spam]: Hi, Taylor Smith! You’ve been pre-approved for a loan up to $5,000. Apply now and get the funds within 24 hours!
# 28.[ham]: Remember to pick up milk and eggs at the store, please!
# 29.[spam]: Did you miss our limited-time offer? Buy one get one free on all electronics! Ends soon. https://www.myshop818.com
# 30.[ham]: Forgot to tell you, the meeting got moved to tomorrow.
# 31.[ham]: Heard from Mom, she said the garden is finally starting to bloom!
# 32.[spam]: Heads up! We detected unusual activity on your bank account. Please verify your recent transactions immediately: https://www.secure304.com.
# 33.[ham]: Forgot my lunch at home. Can you swing by with it?
# 34.[spam]: Exclusive offer! Get 20% off your next order at [clothing store name] - use code SUMMER20.
# 35.[spam]: Hey, your loan application has been pre-approved! Get $5,000 now. Apply here: https://www.myshop378.com
# 36.[ham]: That new coffee shop downtown is actually pretty good, we should check it out sometime.
# 37.[ham]: That movie was surprisingly good! You should watch it.
# 38.[spam]: 🔥 Huge sale happening at Store Outlet! Up to 70% off everything! Shop now before it's gone!
# 39.[ham]: Need me to pick up anything from the store? Running errands now.
# 40.[spam]: Hey, your Amazon order is out for delivery! Track it here: https://www.example734.com
# 41.[spam]: Your Amazon order has been dispatched! Track it here: https://www.bestdeals950.com. Claim your exclusive welcome gift.
# 42.[ham]: Hey, just a heads up, the meeting got moved to 2 pm.
# 43.[ham]: Hey! Just got your text. Yes, totally free tonight, what are you thinking?
# 44.[ham]: Hey! Did you finish that report yet? Mine's due tomorrow, starting to panic a little.
# 45.[spam]: Unlock exclusive savings on your car insurance. Compare quotes from top providers & save up to $500! Get your free quote: [Insurance Link]
# 46.[ham]: Game's on at 7, pizza's at my place. You in?
# 47.[spam]: Urgent: Suspicious activity detected on your account. Please verify your details immediately: https://www.bestdeals1.com
# 48.[spam]: Hey, it's Liam from your college. Remember that grant we talked about? Few spots just opened up, apply now before it's gone: https://www.example805.com
# 49.[ham]: Lunch plans? I was thinking that new Thai place.
# 50.[spam]: You've been pre-approved for a loan up to $5,000. Apply instantly: https://www.onlinestore933.com
# 51.[spam]: Don't miss out! Huge discounts on designer items end tonight. Shop now: https://www.secure271.com
# 52.[spam]: Urgent: Suspicious activity detected on your account. Verify now: https://www.bestdeals540.com
# 53.[spam]: Your Amazon order is out for delivery! Track it here: https://www.onlinestore654.com
# 54.[ham]: Hey, are you still up for grabbing those tacos tonight?
# 55.[ham]: Saw the new Avengers trailer, looks epic! Wanna watch it opening night?
# 56.[spam]: Your account was recently logged in from a new device. If this wasn't you, please verify your identity immediately at: [suspicious URL].
# 57.[spam]: Need cash fast? Get approved for a $5000 loan in minutes! Apply now with our easy online form: [loan website link]
# 58.[spam]: Hey! Need a quick loan? Get approved within minutes! Apply here: https://www.bestdeals576.com
# 59.[spam]: Hey, remember that car insurance quote? We can still save you money. Get a new quote: https://www.secure942.com
# 60.[ham]: Just finished that new Netflix show, totally worth the watch! You seen it?
# 61.[ham]: Ugh, this traffic is brutal. Running late for the meeting.
# 62.[spam]: Need a little extra cash this month? Quick & easy loans available, no credit check required. Apply now: [loan website]
# 63.[ham]: Almost there! See you at the game in 20 mins!
# 64.[ham]: Did you ever find your keys? I’m still looking for mine!
# 65.[ham]: Saw that new movie trailer - looks kinda interesting! Wanna go this weekend?
# 66.[spam]: Your credit score dropped! Possible fraudulent activity detected. Call [Phone Number] immediately.
# 67.[ham]: Just landed in Rome! The pasta here is unbelievable. 🇮🇹
# 68.[ham]: Hey, did you see the game last night?! Crazy finish!
# 69.[ham]: Grocery run later - need anything specific? Thinking of making that pasta dish we like.
# 70.[ham]: OMG, the new cafe downtown has amazing pastries. We should go!
# 71.[spam]: Urgent: Suspicious activity detected on your account. Please verify your details here: https://www.secure118.com
# 72.[ham]: Thinking of you! Let's try that new Thai place downtown this weekend?
# 73.[ham]: Just a heads up, don't forget your lunch today!
# 74.[ham]: Found my keys! Crisis averted.
# 75.[ham]: Almost there! Pizza tonight?
# 76.[spam]: Urgent: Suspicious activity on your account. Verify now to avoid suspension: https://www.onlinestore265.com
# 77.[ham]: Hey, you still coming over tonight? Pizza and movies!
# 78.[spam]: Good news! You've been selected to test our new online game and could win up to $5000! Click here to start playing: https://www.secure811.com
# 79.[ham]: Just a reminder about the meeting tomorrow.
# 80.[spam]: You've been selected for a mystery gift at [Local Store Name]! Just show this message at checkout before Sunday to claim it.
# 81.[spam]: Hey, it's Jake. Remember that business plan we discussed? Funding available now for promising startups. Visit funding-solutions.biz
# 82.[spam]: Still thinking about that summer getaway? Book now and get 40% off all Caribbean cruises! Limited spots available: [advertisement link]
# 83.[ham]: Big game tonight! Hoping our team can pull off a win. 🤞
# 84.[ham]: Just booked that weekend getaway! Get ready for some serious relaxation.
# 85.[ham]: Just saw the game highlights - unreal finish! What did you think?
# 86.[ham]: Just saw that new movie, it was kinda meh tbh. What are you up to this weekend?
# 87.[ham]: Pizza or Chinese for dinner tonight?
# 88.[ham]: Did you finish that report for Mr. Henderson?
# 89.[ham]: Can you send me that presentation by end of day?
# 90.[ham]: Hey! Did you finish that project?
# 91.[spam]: Your package from [Company Name] is arriving tomorrow. Confirm your delivery address to avoid delays: [Delivery confirmation link]
# 92.[spam]: Your card ending in 4789 was just used for $249.99 at WEIRDSTUFF. Not you? Secure your account now: https://www.myshop991.com
# 93.[ham]: Don't forget we're supposed to be at Sarah's at 7!
# 94.[spam]: Don't miss out! Limited-time offer: 50% off designer jeans at BlueStyle.
# 95.[ham]: Hey, forgot to ask, what time is your appointment tomorrow?
# 96.[ham]: Saw that new restaurant you mentioned, gonna try it tonight if you're free?
# 97.[spam]: Hey Sam Martinez, your Amazon Prime subscription is expiring! Renew now for exclusive deals & free shipping! https://www.myshop742.com
# 98.[spam]: Hey, your Amazon order is ready for pickup! Click here: https://www.example877.com
# 99.[spam]: Your loan application is pre-approved. Get up to $5000 today! Apply here: https://www.bestdeals944.com
# 100.[ham]: Just finished the new season of The Crown, absolutely loved it!
# 101.[ham]: Did you see that crazy goal last night?!
# 102.[ham]: Did you finish that report for Mr. Davis?
# 103.[ham]: Just finished that book I was telling you about. So good! You should definitely read it.
# 104.[spam]: You've been pre-approved for a $5,000 loan. Fast cash, no credit check. Apply here: https://www.bestdeals555.com
# 105.[ham]: OMG, you HAVE to watch this new show on Netflix. So good!
# 106.[ham]: Just finished my workout - feeling great! What's on your agenda today?
# 107.[spam]: Quick question! Are you interested in a quick loan? Get approved within minutes. Apply here: https://www.onlinestore833.com
# 108.[ham]: Got the tickets for the game! Should be fun.
# 109.[spam]: Your Amazon order is arriving today! Track it here: https://www.onlinestore272.com
# 110.[ham]: Running a bit late, traffic is a nightmare. Be there as soon as I can!
# 111.[ham]: Hey, did you see that crazy play last night?!
# 112.[spam]: Urgent: Unusual activity on your account. Please verify your recent transaction at secure411.com to prevent suspension.
# 113.[ham]: Hey, can you grab milk and eggs on your way home?
# 114.[spam]: 🔥💰You've been selected for a special reward! Claim it now before it expires: https://www.example538.com 🎁
# 115.[ham]: Big game tomorrow! Think our team's got a shot? 🤞
# 116.[ham]: Did you find your keys yet? I looked everywhere!
# 117.[ham]: Ugh, my phone died. Can you send me the address again?
# 118.[spam]: Hi John Garcia, urgent message regarding your account. We noticed unusual activity. Call us back: [Number]
# 119.[spam]: Hi, this is Marcus from QuickLoans. Need a fast cash boost? Get approved in minutes! Reply YES to learn more.
# 120.[spam]: Your Amazon order has shipped! Track it here: https://www.secure496.com
# 121.[ham]: Saw the new Marvel movie today. Prepare to have your mind blown!
# 122.[ham]: Almost forgot - can you pick up milk on your way home?
# 123.[ham]: OMG, have you seen the new Marvel movie?!
# 124.[ham]: Almost finished with that report, should have it to you by noon.
# 125.[ham]: Guess what? I finally finished reading that novel everyone was talking about. It was a total page-turner!
# 126.[ham]: Just finished binging that new show everyone's been talking about! What did you think?
# 127.[ham]: Mom said to remind you about the family dinner this weekend.
# 128.[spam]: Hey Jane Martinez, your loan pre-approval is ready! Get up to $50,000 with low rates. Apply now: https://www.example514.com
# 129.[spam]: Hey! Did you buy a lottery ticket? Check your numbers now, you might have won a HUGE prize! https://www.example666.com 💰
# 130.[spam]: Hey Chris Smith, your loan pre-approval is ready! Get up to $5000 quickly: https://www.example465.com
# 131.[ham]: Just saw the game! Crazy finish, right?
# 132.[ham]: Just finished that new series, it was actually pretty good! Wanna watch something tonight?
# 133.[ham]: Heading to the shops, need anything?
# 134.[spam]: Your Amazon order has shipped! Track it here: https://www.bestdeals227.com Don't miss out!
# 135.[spam]: Heard you're looking for a new car. Check out our incredible deals on 2023 models, with discounts up to 25%! [marketing link]
# 136.[ham]: Forgot to ask, did you finish that report?
# 137.[ham]: Just saw your post, haha! That dog is hilarious.
# 138.[ham]: Happy birthday, sis! Hope you have an amazing day filled with cake and laughter. 🎉
# 139.[spam]: Account alert: Suspicious activity detected. Verify your transaction now to avoid account suspension: https://www.onlinestore841.com
# 140.[ham]: Hey, just finished that report. Ready for the weekend!
# 141.[ham]: Hey, fancy grabbing a coffee later?
# 142.[ham]: Mom's asking when you're coming over for dinner.
# 143.[spam]: Urgent: Suspicious activity detected on your account. Verify immediately to prevent suspension: https://www.example148.com
# 144.[spam]: Hi John Miller, get a $500 loan approved in minutes! Apply here: https://www.example874.com
# 145.[spam]: Still thinking about that summer getaway? Get pre-approved for a personal loan with rates as low as 6.99%: https://www.onlinestore372.com
# 146.[spam]: Urgent: Suspicious activity detected on your account. Verify your details now to avoid suspension: https://www.example286.com
# 147.[ham]: Just a heads up, I’m grabbing sushi for dinner. Want me to grab you some?
# 148.[ham]: OMG did you see the ending of that movie?! Crazy!
# 149.[ham]: Hey, did you remember to grab milk at the store? We're almost out!
# 150.[spam]: Hey, remember that amazing restaurant we talked about? They're having a two-for-one deal this weekend! https://www.bestdeals531.com
# 151.[ham]: Feeling overwhelmed with work. Need a serious dose of Friday ASAP.
# 152.[ham]: Heading to the beach this weekend, wanna join?
# 153.[ham]: The game got cancelled due to rain. Bummer!
# 154.[ham]: Just got back from the beach. Sunburnt but happy! Hope your day's going well.
# 155.[spam]: Your Amazon order is delayed. Get 20% off your next purchase with code: FALL20.
# 156.[spam]: We noticed some unusual activity on your Netflix account. Please update your payment details here to avoid interruption: netflix-verify.me
# 157.[ham]: Weather's supposed to be amazing this weekend, wanna go hiking?
# 158.[spam]: Limited time offer! Get 50% off all summer styles at TrendyThreads. Shop now: https://www.bestdeals687.com
# 159.[ham]: OMG, you HAVE to see this new movie! Let's go this weekend?
# 268.[spam]: Hi, we noticed an unusual transaction on your card. Did you make a purchase of $479.00 at [merchant]? Reply YES or NO.
# 269.[ham]: Dinner plans tonight? Thinking Italian?
# 270.[ham]: Forgot to ask - are you free for dinner Friday? Thinking Italian.
# 271.[spam]: You've been pre-approved for a loan up to £5,000. Check your eligibility: https://www.example691.com
# 272.[spam]: Hey Jane Hernandez, check out our flash sale - 50% off everything at [Website]! Ends tonight!
# 273.[ham]: Just finished that new Netflix show - you gotta watch it! So good.
# 274.[ham]: Just saw the trailer for that new movie - looks good! Wanna go this weekend?
# 275.[spam]: Need a quick loan? Get approved within minutes. Apply here: https://www.bestdeals439.com
# 276.[ham]: Did you finish that presentation yet? Need a hand with anything?
# 277.[spam]: Hey Emily Miller, your application for a $5,000 loan has been pre-approved! Get the funds in your account today! Click here: https://www.example991.com
# 278.[spam]: Hey, it's Sarah from college! Lost your number, wanted to see if you’re free to catch up sometime? I’m in town next week.
# 279.[spam]: Last chance for the sale! Up to 70% off everything. Shop now: https://www.example117.com
# 280.[spam]: Hi Emily Jones, we've been trying to reach you about your eligibility for a government grant. Click here: https://www.onlinestore41.com
# 281.[spam]: Your account has been temporarily suspended due to suspicious activity. Verify now: https://www.secure13.com
# 282.[ham]: Heading to the game tonight, you in?
# 283.[ham]: Just landed in Rome! The pizza is already amazing. Wish you were here!
# 284.[spam]: Loan approved! Get $5,000 within 24 hours. Apply now: https://www.myshop534.com
# 285.[ham]: Spurs game was insane! What a comeback!
# 286.[ham]: Did you finish that report yet? Need to know when I can get it.
# 287.[spam]: Free gas card giveaway! Just reply YES to enter.
# 288.[spam]: Your lottery numbers have been drawn! Check if you've won: https://www.myshop775.com
# 289.[spam]: Urgent: Your loan application has been pre-approved. Get up to $5,000 today! Apply now: https://www.example710.com
# 290.[spam]: Hey! Just saw your profile, thought you might be interested in our new dating app. Check it out: https://www.example808.com
# 291.[ham]: Hey! Running late, grabbing a coffee, will be there in 20.
# 292.[spam]: Hi Jane Davis, did you see our new summer sale? Up to 70% off everything! Shop now before it ends! https://www.bestdeals931.com
# 293.[ham]: Heard any good jokes lately? I could use a laugh.
# 294.[ham]: My little sister just built an epic sandcastle! I'll send you a pic later.
# 295.[spam]: Unlock exclusive travel deals! Limited-time offer: 30% off flights to Rome. Book now at https://www.myshop666.com.
# 296.[spam]: Get a $500 loan approved in minutes! No credit check needed. Apply now: https://www.onlinestore14.com
# 297.[ham]: Just landed! Will text you later, got a taxi.
# 298.[spam]: Did you try claiming your share from that class action lawsuit against Big Telco? Deadline's next week: SecureClaim.net
# 299.[spam]: Liam, remember that project you started? We're launching soon and need your input! Reply YES to reconnect.
# 300.[spam]: Hey, it's Liam from Uni Loans. See if you qualify for a lower student loan rate today - could save you hundreds! https://www.example932.com
# 301.[ham]: Just finished that new thriller, totally worth the read! Let me know if you want to borrow it.
# 302.[spam]: Urgent: Suspicious activity detected on your account. Verify now: https://www.example268.com
# 303.[spam]: Hi Jordan Miller, remember that cute dress you looked at on TrendyThreads? It's now 30% off for a limited time! trendythreads.com/sale
# 343.[ham]: OMG, the movie was so good! Let's talk soon!
# 344.[spam]: Your Amazon order is ready for pickup. Click this link to view the details: https://www.onlinestore826.com
# 345.[ham]: LOL, you won't BELIEVE what happened at work today... I'll tell you later over drinks?
# 346.[spam]: Urgent: Suspicious activity detected on your account. Call 555-0199 immediately.
# 347.[spam]: Someone tried to access your account. Confirm it's you: https://www.myshop799.com Reply STOP to opt-out.
# 348.[spam]: We have an exclusive offer for you: free tickets to the upcoming music festival! Claim your spot: https://www.onlinestore67.com
# 349.[ham]: Thinking of going to the beach this weekend. Wanna join?
# 350.[ham]: Crazy traffic today! Almost there.
# 351.[spam]: Hey, quick question! Thinking of refinancing my mortgage, any recs? Found a great deal with 2.9% APR.
# 352.[ham]: Sunshine and a walk sound amazing right now. Wanna join?
# 353.[ham]: Just saw that new movie, it was amazing! Wanna go this weekend?
# 354.[spam]: Need a quick loan? Get approved instantly. Apply now at bestdeals616.com and get the cash you need.
# 355.[ham]: Hey, just picked up the ingredients for dinner. Think I'm gonna try that pasta recipe we saw!
# 356.[ham]: Saw that movie trailer - looks hilarious! Free next Friday?
# 357.[spam]: Remember that $50 off coupon from BeautyBox? It's expiring soon! Treat yourself to something nice before it's gone: https://www.bestdeals372.com
# 358.[spam]: Hi Taylor Williams, You've been selected for a chance to win a luxury vacation! Click here: https://www.example752.com
# 359.[ham]: Game's on at 7 tonight, pizza at my place beforehand?
# 360.[spam]: Your parcel is awaiting delivery but we need confirmation of your address and a small shipping fee payment (£1.99). Please confirm here: https://www.myshop753.com
# 361.[spam]: Need cash fast? Apply for a loan in minutes. No credit check needed. Text YES to 77777.
# 362.[ham]: Just saw the new Avengers trailer, looks insane!
# 363.[spam]: Hi Jordan Hernandez, just a reminder about your upcoming appointment at [Clinic Name] on [Date] at [Time]. Confirm here: https://www.example627.com
# 364.[spam]: Claim your exclusive prize! Visit https://www.example361.com within 24 hrs.
# 365.[ham]: Heads up, I'm running a little late. Be there in 20!
# 366.[spam]: Hey, it's Liam from that networking event last week. Found something interesting you might like about boosting your LinkedIn reach - https://www.bestdeals378.com
# 367.[spam]: Flash sale! Up to 70% off everything at bestdeals863.com! Don't miss out! Shop now!
# 368.[ham]: Forgot to tell you, the game starts at 7, not 8!
# 369.[spam]: Hi, it's been a while! We miss you at [Local Restaurant]. Come enjoy 20% off any entrée with this code: WELCOME20 [Restaurant website]
# 370.[ham]: Dinner's at 7 tonight, be there or be square! ;)
# 371.[spam]: Is this Morgan Jones? It's Mark from [Mortgage company]. Just wanted to see if you're still looking at refinancing options with these lower rates!
# 372.[ham]: Weather's perfect for a hike tomorrow, wanna go?
# 373.[spam]: Hi, it's Mark. Remember that home renovation project you were planning? My team has an opening next month - free quote & 10% off materials this week only! Mark's Home Improv.
# 374.[ham]: How's the project going? Need any help?
# 375.[spam]: Your account has been flagged for unusual activity. Please verify your details here: https://www.onlinestore518.com
# 376.[spam]: Hey! Your credit score has just been updated. Get your free report now!
# 377.[spam]: Hi Jane Johnson, you've been selected for a special draw! Claim your prize now before it expires! https://www.example892.com
# 416.[spam]: Your package is awaiting confirmation for redelivery, please confirm address & small fee here: https://www.myshop941.com
# 417.[spam]: Still thinking about that kitchen upgrade? Get pre-approved for a home improvement loan with rates as low as 2.99% APR. Apply now: [loan offer link]
# 418.[spam]: Your Amazon order is ready for dispatch! Track it here: https://www.onlinestore960.com
# 419.[spam]: Did you apply for that debt relief program last month? We've finalized your application and you're pre-approved for up to $15,000! Call (555) 123-4567 to claim it.
# 420.[ham]: Heard back from the job, interview's scheduled for next week! Wish me luck!
# 421.[ham]: Just saw the funniest cat video. You HAVE to see it later!
# 422.[ham]: Did you remember to pick up milk from the store? Running low.
# 423.[ham]: Just saw the new Spiderman trailer - looks amazing!
# 424.[ham]: Forgot to pick up the dry cleaning. Can you grab it for me?
# 425.[spam]: Hey! Your loan application is approved. Get £5000 today. Apply here: https://www.bestdeals640.com
# 426.[spam]: Hey, is this Sarah? We found some unclaimed funds under your name. Call (555) 123-4567 to claim them before they expire!
# 427.[ham]: Did you remember to pick up milk and eggs? Need them for the pancakes tomorrow.
# 428.[ham]: Just saw the funniest meme, you have to see it later!
# 429.[ham]: Mom's calling again, can you answer her?
# 430.[spam]: Hey, your Amazon order's delayed. Get 20% off next purchase with code DELAY20.
# 431.[spam]: Urgent: Unusual activity detected on your card. Verify purchase now to prevent suspension: secure-alert.online
# 432.[spam]: Hey! Get 50% off your first ride with our new taxi service. Use code: RIDE50
# 433.[ham]: Movie night at my place this weekend? Let me know if you're in!
# 434.[ham]: Just got the email - meeting's been moved to Thursday.
# 435.[ham]: So, I accidentally booked the wrong train ticket... big oops!
# 436.[ham]: Movie night at my place this Saturday? I'm thinking "Everything Everywhere All at Once".
# 437.[spam]: You've been pre-approved for a loan of up to $50,000. Get started today: https://www.example980.com
# 438.[ham]: Morning! Don't forget we have that meeting at 2.
# 439.[spam]: You've been selected to test our newest beauty product for FREE! Just cover shipping: [fake website link]
# 440.[ham]: Just saw the cutest dog at the park. Made me miss yours!
# 441.[spam]: Need a quick cash boost? Get a loan offer within minutes. Apply now: https://www.secure383.com
# 442.[spam]: Hi there! You've been selected for a special prize draw! Click to claim: https://www.secure615.com
# 443.[ham]: Feeling kinda blah today. Need coffee and a serious dose of sunshine. Hope your day is better!
# 444.[ham]: Just made the most amazing lasagna! You should come over next week, I'll make another one.
# 445.[spam]: Your loan application has been approved! Get up to $5,000 within 24 hours. Click here: https://www.example375.com
# 446.[spam]: Did you forget something in your online cart at Store Tech? We've saved it for you & are offering free shipping to complete your purchase! Shop Now: [URL]
# 447.[ham]: Just got back from the store. Forgot the milk again, ugh!
# 448.[ham]: Weather's perfect for a bike ride later, wanna go?
# 449.[ham]: Ordered pizza for dinner! Want me to grab you some?
# 450.[ham]: Need help with this excel sheet, can you call me?
# 451.[spam]: Hey, is this Sarah? Found your number on a survey entry for a free spa day! Let me know if you're interested in claiming it.
# 452.[spam]: 🔥 Limited-time offer: Get 50% off your next grocery order! Use code SAVEBIG at checkout.
# 453.[spam]: Get 50% off your next meal at Pizza Palace! Show this text at checkout.
# 454.[spam]: Hey, we noticed you left something in your cart at myshop119.com. Finish your purchase now and get free shipping!
# 455.[ham]: Hey, you still up for dinner tonight?
# 456.[ham]: Almost missed my bus this morning! Running late but at least the sun is shining.
# 457.[ham]: Hey, did you remember it's your turn to pick up the kids from practice today?
# 458.[spam]: Hey, it's Sarah from your local pharmacy. Just a heads-up, your prescription is ready for pickup, and we're offering 20% off all skincare this week!
# 459.[spam]: 🔥💰 Jackpot alert! Your lucky numbers are in! Claim your winnings at https://www.bestdeals831.com.
# 460.[ham]: Going to the game tonight! Should be a good one, you in?
# 461.[spam]: Pre-approved for a $5,000 personal loan! Need extra cash for bills or vacation? Check your rate now with no impact to your credit score: [Loan Website]
# 462.[spam]: Your lottery numbers matched! Claim your prize immediately: https://www.onlinestore659.com Claim deadline: [Date].
# 463.[spam]: You've been selected for a VIP experience! Click here for details and a chance to win a prize: https://www.secure217.com
# 464.[spam]: Your package is delayed due to unpaid shipping fees. Pay $2.99 immediately to avoid return to sender: [fake shipping link]
# 465.[spam]: Hey, quick question about your recent credit application. Can you give me a call? 555-0123
# 466.[ham]: Don't forget to pick up milk on your way home. The fridge is looking a little sad.
# 467.[ham]: My flight got delayed. Won't be there till 9pm now. So sorry!
# 468.[spam]: Urgent: Suspicious activity detected on your account. Verify now: https://www.onlinestore89.com
# 469.[spam]: Hey there! Your account has been flagged for suspicious activity. Call us ASAP at 555-0100.
# 470.[spam]: Hey! We're giving away a free trip to Hawaii! Just reply YES to enter.
# 471.[spam]: Psst... Student loans got you down? We can cut your payments in half. See if you qualify: reliefprogram.com
# 472.[spam]: Want a quick cash boost? Get approved for a loan in minutes. Apply here: https://www.onlinestore767.com
# 473.[spam]: Just saw you’re in [city name]. Wanna grab dinner? I know this amazing new Italian place. Oh, also, huge sale on [product they might be interested in] this week!
# 474.[ham]: Thinking about booking that trip, wanna go?
# 475.[spam]: Hey! Get 50% off all summer styles at [Shop name]. Sale ends Sunday. Tap to shop: https://www.onlinestore294.com
# 476.[spam]: Your card was just used for a $789.52 purchase at BestBuy. If this wasn't you, please call us immediately at 1-800-555-HELP.
# 477.[spam]: Hey, check out this amazing offer! Get a free gift with your next purchase at Store USA: https://www.myshop568.com🎁
# 478.[spam]: Hey! Just got a special offer for you at Store Outlet - up to 60% off summer styles! Check it out: https://www.secure94.com
# 479.[ham]: Thinking of hitting up that new hiking trail this weekend. Wanna join?
# 480.[spam]: Hey, it's Liam from college. Remember that lottery pool we did? Turns out we actually won a smaller prize this time, Claim your share here before it expires: https://www.example67.com
# 481.[ham]: Thinking of going for a run later, wanna join?
# 482.[ham]: Just a reminder about dinner at 7 tonight - bring the wine!
# 483.[ham]: Hey, did you see the game last night? That ending was wild!
# 484.[spam]: Hey, remember that dress you liked? It's back in stock + 20% off today only! https://www.secure673.com
# 485.[ham]: Almost forgot! Mom asked if you're coming over for dinner on Saturday.
# 486.[ham]: Hey, are you still coming over tonight? Bring snacks!
# 487.[spam]: You've been pre-selected for a special prize draw! Claim your reward: https://www.bestdeals941.com
# 1985.[spam]: Urgent: Your bank account has been locked due to suspicious activity. Verify now: https://www.bestdeals828.com
# 1986.[ham]: Saw that new superhero movie - it was surprisingly good! We should go next week.
# 1987.[spam]: Hey Casey Johnson, there's a new draw for the weekly lottery. Tickets are on sale. Check it out: https://www.example814.com
# 1988.[ham]: Did you finish that presentation? How'd it go?
# 1989.[ham]: Hey, still want to grab coffee tomorrow?
# 1990.[spam]: Your package is arriving, pay the $2.50 delivery fee to avoid delays: tinyurl.com/track-it-now
# 1991.[ham]: Just saw the craziest movie! You HAVE to watch "Everything Everywhere All at Once." Let's talk about it later.
# 1992.[ham]: Just made a killer batch of cookies, swing by later if you want some!
# 1993.[ham]: Found a cool new hiking trail near the lake. Wanna check it out next weekend?
# 1994.[ham]: Hey, are we still on for that hike tomorrow morning? 8 AM at the trailhead?
# 1995.[spam]: Hi Chris Garcia, your loan application is pre-approved! Get up to $5000. Apply now: https://www.onlinestore961.com
# 1996.[ham]: Hey, did you end up getting those concert tickets?
# 1997.[spam]: Urgent alert: Unusual activity detected on your bank account. Please verify your recent transactions immediately: [Suspicious link]
# 1998.[ham]: Update: Presentation went well! Pizza's on me tonight. 🎉
# 1999.[spam]: Claim your FREE gift card from Amazon. Only 3 left! Click this link to get yours: https://www.myshop880.com
# 2000.[spam]: Hey, is this Sarah? It's Liam from the hiking group - we're doing a gear swap meet next weekend. Thought you might be interested!
# 2001.[spam]: Did you authorize a $850 purchase at BestBuy with your [Bank Name] card ending in 4729? Reply YES or NO. If NO, call [Fraud Number] immediately.
# 2002.[ham]: Just landed! Will call you in an hour.
# 2003.[spam]: Hey! Your application for a $5000 loan has been approved. Reply YES to claim it now.
# 2004.[spam]: Just got your entry! You're in the draw for the Grand Prize. Good luck! Check results: https://www.myshop582.com
# 2005.[ham]: Don't forget to RSVP for Sarah's party by Friday!
# 2006.[ham]: Pizza or pasta tonight? I'm starving!
# 2007.[ham]: Mom says dinner's ready, you coming?
# 2008.[ham]: Did you finish that book you were reading? Any good?
# 2009.[spam]: Your loan application is approved! Get $5,000 today. Apply now: https://www.myshop592.com
# 2010.[spam]: Did you request a password reset for your Netflix account? If not, secure your account now: https://www.bestdeals763.com
# 2011.[ham]: Just made the best pasta carbonara ever! Come over tomorrow night, I'll make you some.
# 2012.[spam]: Claim your exclusive lottery reward! Details here: https://www.bestdeals426.com
# 2013.[ham]: Just saw the game, what a finish! You catch it?
# 2014.[ham]: Grandma called, she says hi and wants to know if you're free for dinner next Sunday.
# 2015.[spam]: Hi Morgan Garcia, your application for a loan of £5,000 has been conditionally approved. Click here to finalize: https://www.example18.com
# 2016.[spam]: Bank alert: Suspicious activity detected on your account. Verify now: https://www.secure971.com
# 2017.[ham]: Dude, what are you even doing tonight? Free?
# 2018.[spam]: Your number was randomly selected for a chance to win a Tesla! Claim your entry before midnight: prize-giveaway.com
# 2019.[ham]: OMG, that new coffee shop is the best! We should go!
# 2020.[spam]: Hey, your recent transaction triggered a security alert. Call us back ASAP: 555-0199
# 2021.[ham]: Movie night at my place this Friday? Thinking something 80s!
# 2022.[spam]: Your order is ready! Pick it up at Store Depot and get a free dessert. Show this msg!
# 2023.[spam]: Hi Jane Brown, your loan application is pre-approved! Get up to $5000 with low interest. Apply here: https://www.secure766.com
# 2024.[ham]: Just saw the game was cancelled. Gutted! Fancy a takeaway instead?
# 2025.[ham]: Ugh, this meeting is so boring. Send help (and coffee)!
# 2026.[ham]: Ugh, my car's making a weird noise. Think I need to get it checked.
# 2027.[ham]: Heard the game got postponed. Ugh, so annoying!
# 2028.[spam]: Your card ending in 4789 was just used for $150 at [Online Store]. If this wasn't you, secure your account here: [Suspicious Link]
# 2029.[spam]: Hey, check out these amazing deals! Up to 70% off on summer essentials. Shop now: https://www.secure850.com
# 2030.[spam]: Your loan application has been approved! Get funds within 24 hours: https://www.secure945.com
# 2031.[ham]: Pizza tonight? I'm craving some!
# 2032.[ham]: Just saw the craziest play at the game! You wouldn't believe it.
# 2033.[ham]: Just saw the craziest goal in the soccer game! You missed a good one.
# 2034.[spam]: Hey, your Amazon order is out for delivery! Track it here: https://www.example995.com
# 2035.[ham]: Did you finish the project draft? Let me know how it went!
# 2036.[ham]: Just finished that book you recommended, wow! Seriously mind-blowing.
# 2037.[spam]: Someone just transferred $1000 into your account! Claim it now before it's returned to sender: https://www.bestdeals63.com
# 2038.[ham]: Did you finish that report yet? Need it by end of day.
# 2039.[spam]: Want to win a $1,000 Amazon gift card? Click here to enter: https://www.example327.com
# 2040.[ham]: Movie tonight? Thinking of that new action flick.
# 2041.[spam]: Limited time offer! Get approved for a loan up to $5,000 today. Apply now and receive the funds within 24 hours.
# 2042.[ham]: Did you remember to grab milk from the store?
# 2043.[spam]: Get 50% off your first ride with code SPRING2024! Download the app https://www.myshop641.com
# 2044.[ham]: Thinking of making that pasta tonight. Wanna come over?
# 2045.[spam]: Hi John Jones, your recent Amazon order has been shipped! Track it here: https://www.onlinestore46.com
# 2046.[ham]: Crazy weather, huh? Hope you're having a good day!
# 2047.[spam]: Hey Chris Martinez, your ticket number has won a prize! Claim it now and don't miss out https://www.bestdeals297.com
# 2048.[ham]: On my way to the gym, wanna join? Leg day today!
# 2049.[ham]: Big presentation went well! Time to celebrate with some tacos.
# 2050.[ham]: Hey, still keen for the game tonight? Kick off is at 7!

# %%
input_file = "../../../Data/English/2. Synthetic/synthetic_english_sms_gemini.csv"

synthetic = pd.read_csv(input_file, encoding='latin1')

# %%
synthetic
# Out:
#                                                 message label
# 0     Hey! Just saw your recent Instagram post. Thin...  spam
# 1     Urgent! Your loan application is approved. Get...  spam
# 2     Want to grab pizza and watch the game tonight?...   ham
# 3     ð¥ð° Limited-time offer: Upgrade your phon...  spam
# 4     You've been selected as a finalist for our $10...  spam
# ...                                                 ...   ...
# 2045  Crazy weather, huh? Hope you're having a good ...   ham
# 2046  Hey Chris Martinez, your ticket number has won...  spam
# 2047   On my way to the gym, wanna join? Leg day today!   ham
# 2048  Big presentation went well! Time to celebrate ...   ham
# 2049  Hey, still keen for the game tonight? Kick off...   ham
#
# [2050 rows x 2 columns]
